# %%
import esm
import sys, os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from scipy.stats import spearmanr

cmap = plt.get_cmap("tab20c")
sns.set(font_scale=1)
pd.set_option('display.max_columns', 50)
sns.set_style("white")

file_path = "/home/ch3849/SAE_mut/code/model_relu"
sys.path.append(file_path)
from dictionary import AutoEncoder

# %% [markdown]
# ### load models and data

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

esm_model, alphabet = esm.pretrained.esm2_t33_650M_UR50D()
esm_model.eval()  # disables dropout for deterministic results
esm_model = esm_model.to(device)
batch_converter = alphabet.get_batch_converter()

model = 250417
chk = 80000
chk_path = f'/share/vault/Users/ch3849/esm_sae/model/{model}/checkpoints/step_{chk}.pt'
sae = AutoEncoder.from_pretrained(chk_path)
sae.eval()  # disables dropout for deterministic results
sae = sae.to(device)
# Out:
# /home/ch3849/SAE_mut/code/model_relu/dictionary.py:108: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = t.load(path)

# %%
os.chdir('/nfs/user/Users/ch3849/esm_sae/gate_mut')
embed = pickle.load(open('embedding_412wt.pkl', 'rb'))
label = pickle.load(open('training_label.pkl', 'rb'))

embed = {key:value.to(device) for key, value in embed.items()}
label = {key:value.to(device) for key, value in label.items()}

df = pd.read_csv('412wt_info.csv')
df_train = df[df['split'] == 'train'].reset_index(drop=True)
df_test = df[df['split'] == 'test'].reset_index(drop=True)

# %% [markdown]
# ### gate model

# %%
lr = 1e-3
n_epoch = 54
lambda_sparse = 1

# %%
class BinaryGate(nn.Module):
    def __init__(self, embed_dim):
        super().__init__()
        self.logits = nn.Parameter(torch.zeros(embed_dim))

    def forward(self):
        probs = torch.sigmoid(self.logits)
        # STE: forward uses hard 0/1, backward uses gradient through probs
        hard = (probs > 0.5).float()
        gates = hard + probs - probs.detach()
        return gates, probs  # return both for logging if desired

# %%
# ---------------------
# Differentiable "soft rank" -> used to compute a differentiable Spearman proxy
# Implementation: soft_rank_i = 1 + sum_j sigmoid((x_j - x_i)/tau)
# tau controls smoothness (smaller => closer to true rank)
# ---------------------
def soft_rank(x: torch.Tensor, tau: float = 1e-2):
    # x: (N,) or (N, )
    x_i = x.unsqueeze(0)   # (1, N)
    x_j = x.unsqueeze(1)   # (N, 1)
    # pairwise differences x_j - x_i -> shape (N, N)
    pairwise = (x_j - x_i) / tau
    # sigmoid sums: for each i, count how many x_j > x_i
    s = torch.sigmoid(pairwise)
    ranks = 1.0 + s.sum(dim=1)  # (N,)
    return ranks

def pearson_corr(x: torch.Tensor, y: torch.Tensor, eps=1e-8):
    x_mean = x.mean()
    y_mean = y.mean()
    xm = x - x_mean
    ym = y - y_mean
    r_num = (xm * ym).sum()
    r_den = torch.sqrt((xm * xm).sum() * (ym * ym).sum() + eps)
    return r_num / (r_den + eps)

def get_input_label(i, split='train'):
    if split == 'test':
        pro, seq = df_test.loc[i, ['WT_name', 'aa_seq']]
    else:
        pro, seq = df_train.loc[i, ['WT_name', 'aa_seq']]
    batch_labels, batch_strs, batch_tokens = batch_converter([(pro, seq)])
    batch_tokens = batch_tokens[0,1:-1].to(device)

    embed_pro = embed[pro][0,1:-1].to(device)
    label_pro = label[f'{pro}_{split}'].to(device)

    return pro, batch_tokens, embed_pro, label_pro

def get_llr(gated_recon, batch_tokens, label_pro):
    logits = esm_model.lm_head(gated_recon)
    log_probs = torch.log_softmax(logits, dim=1)
    
    llr = log_probs[:,4:24] - log_probs[range(len(batch_tokens)), batch_tokens].unsqueeze(1)
    llr = llr.reshape(-1)

    mask = ~torch.isnan(label_pro)

    return llr[mask], label_pro[mask]

# %%
for p in sae.parameters():
    p.requires_grad = False
for p in esm_model.parameters():
    p.requires_grad = False

gate = BinaryGate(40960).to(device)

optimizer = optim.Adam([gate.logits], lr=lr)
optimizer.zero_grad()

# %%
running_spearman = 0.0
eval_spearman = 0.0
test_spearman = 0.0

for epoch in range(n_epoch):
    gate.train()
    for i in df_train.index:
        pro, batch_tokens, embed_pro, label_pro = get_input_label(i, split='train')

        with torch.no_grad():
            sae_hidden = sae.encode(embed_pro)
        gates, gate_probs = gate()                 
        gated_sae_hidden = sae_hidden * gates
        gated_recon = sae.decode(gated_sae_hidden)

        llr, label_pro = get_llr(gated_recon, batch_tokens, label_pro)

        spearman_approx = pearson_corr(soft_rank(llr), soft_rank(label_pro))

        sparsity_loss = lambda_sparse * gate_probs.mean()
        loss = (-spearman_approx + sparsity_loss) / len(df_train)

        loss.backward()
        running_spearman += spearman_approx

    optimizer.step()
    optimizer.zero_grad()

    gate.eval()
    gates, gate_probs = gate()
    for i in df_train.index:
        pro, batch_tokens, embed_pro, label_pro = get_input_label(i, split='eval')

        with torch.no_grad():
            sae_hidden = sae.encode(embed_pro)
            gated_sae_hidden = sae_hidden * gates
            gated_recon = sae.decode(gated_sae_hidden)

            llr, label_pro = get_llr(gated_recon, batch_tokens, label_pro)

        eval_spearman += spearmanr(llr.cpu().numpy(), label_pro.cpu().numpy()).correlation

    for i in df_test.index:
        pro, batch_tokens, embed_pro, label_pro = get_input_label(i, split='test')

        with torch.no_grad():
            sae_hidden = sae.encode(embed_pro)
            gated_sae_hidden = sae_hidden * gates
            gated_recon = sae.decode(gated_sae_hidden)

            llr, label_pro = get_llr(gated_recon, batch_tokens, label_pro)
        test_spearman += spearmanr(llr.cpu().numpy(), label_pro.cpu().numpy()).correlation

    print(f"epoch {epoch}; open gates={gates.sum().item()}; sparsity_loss={sparsity_loss.item():.4f}; running_spearman={running_spearman / len(df_train):.4f}; eval_spearman={eval_spearman / len(df_train):.4f}; test_spearman={test_spearman / len(df_test):.4f}")
    if test_spearman / len(df_test) > 0.57 and gates.sum().item() < 1410:
        break

    running_spearman = 0.0
    eval_spearman = 0.0
    test_spearman = 0.0
# Out:
# epoch 0; open gates=2004.0; sparsity_loss=0.5000; running_spearman=-0.2092; eval_spearman=0.5522; test_spearman=0.5528
# epoch 1; open gates=2001.0; sparsity_loss=0.4998; running_spearman=0.5616; eval_spearman=0.5522; test_spearman=0.5528
# epoch 2; open gates=1927.0; sparsity_loss=0.4995; running_spearman=0.5616; eval_spearman=0.5754; test_spearman=0.5683
# epoch 3; open gates=1856.0; sparsity_loss=0.4993; running_spearman=0.5841; eval_spearman=0.5793; test_spearman=0.5702
# epoch 4; open gates=1809.0; sparsity_loss=0.4991; running_spearman=0.5879; eval_spearman=0.5822; test_spearman=0.5745
# epoch 5; open gates=1774.0; sparsity_loss=0.4989; running_spearman=0.5905; eval_spearman=0.5855; test_spearman=0.5790
# epoch 6; open gates=1746.0; sparsity_loss=0.4986; running_spearman=0.5937; eval_spearman=0.5862; test_spearman=0.5734
# epoch 7; open gates=1712.0; sparsity_loss=0.4984; running_spearman=0.5946; eval_spearman=0.5874; test_spearman=0.5773
# epoch 8; open gates=1679.0; sparsity_loss=0.4982; running_spearman=0.5948; eval_spearman=0.5864; test_spearman=0.5764
# epoch 9; open gates=1651.0; sparsity_loss=0.4979; running_spearman=0.5941; eval_spearman=0.5871; test_spearman=0.5782
# epoch 10; open gates=1626.0; sparsity_loss=0.4977; running_spearman=0.5952; eval_spearman=0.5864; test_spearman=0.5699
# epoch 11; open gates=1602.0; sparsity_loss=0.4975; running_spearman=0.5937; eval_spearman=0.5888; test_spearman=0.5703
# epoch 12; open gates=1581.0; sparsity_loss=0.4972; running_spearman=0.5960; eval_spearman=0.5925; test_spearman=0.5725
# epoch 13; open gates=1563.0; sparsity_loss=0.4970; running_spearman=0.6004; eval_spearman=0.5879; test_spearman=0.5691
# epoch 14; open gates=1559.0; sparsity_loss=0.4968; running_spearman=0.5977; eval_spearman=0.5877; test_spearman=0.5700
# epoch 15; open gates=1549.0; sparsity_loss=0.4965; running_spearman=0.5973; eval_spearman=0.5903; test_spearman=0.5697
# epoch 16; open gates=1541.0; sparsity_loss=0.4963; running_spearman=0.5998; eval_spearman=0.5889; test_spearman=0.5647
# epoch 17; open gates=1540.0; sparsity_loss=0.4961; running_spearman=0.5979; eval_spearman=0.5900; test_spearman=0.5691
# epoch 18; open gates=1539.0; sparsity_loss=0.4958; running_spearman=0.5997; eval_spearman=0.5842; test_spearman=0.5607
# epoch 19; open gates=1528.0; sparsity_loss=0.4956; running_spearman=0.5922; eval_spearman=0.5862; test_spearman=0.5593
# epoch 20; open gates=1515.0; sparsity_loss=0.4953; running_spearman=0.5940; eval_spearman=0.5897; test_spearman=0.5691
# epoch 21; open gates=1505.0; sparsity_loss=0.4951; running_spearman=0.5986; eval_spearman=0.5898; test_spearman=0.5722
# epoch 22; open gates=1496.0; sparsity_loss=0.4949; running_spearman=0.5994; eval_spearman=0.5881; test_spearman=0.5668
# epoch 23; open gates=1483.0; sparsity_loss=0.4946; running_spearman=0.5949; eval_spearman=0.5856; test_spearman=0.5622
# epoch 24; open gates=1473.0; sparsity_loss=0.4944; running_spearman=0.5920; eval_spearman=0.5894; test_spearman=0.5669
# epoch 25; open gates=1466.0; sparsity_loss=0.4942; running_spearman=0.5974; eval_spearman=0.5893; test_spearman=0.5664
# epoch 26; open gates=1461.0; sparsity_loss=0.4939; running_spearman=0.5966; eval_spearman=0.5892; test_spearman=0.5640
# epoch 27; open gates=1454.0; sparsity_loss=0.4937; running_spearman=0.5955; eval_spearman=0.5890; test_spearman=0.5591
# epoch 28; open gates=1449.0; sparsity_loss=0.4935; running_spearman=0.5972; eval_spearman=0.5870; test_spearman=0.5588
# epoch 29; open gates=1448.0; sparsity_loss=0.4932; running_spearman=0.5970; eval_spearman=0.5839; test_spearman=0.5573
# epoch 30; open gates=1449.0; sparsity_loss=0.4930; running_spearman=0.5952; eval_spearman=0.5857; test_spearman=0.5665
# epoch 31; open gates=1443.0; sparsity_loss=0.4928; running_spearman=0.5962; eval_spearman=0.5817; test_spearman=0.5678
# epoch 32; open gates=1427.0; sparsity_loss=0.4925; running_spearman=0.5927; eval_spearman=0.5914; test_spearman=0.5736
# epoch 33; open gates=1419.0; sparsity_loss=0.4923; running_spearman=0.5996; eval_spearman=0.5887; test_spearman=0.5691
# epoch 34; open gates=1408.0; sparsity_loss=0.4921; running_spearman=0.5954; eval_spearman=0.5844; test_spearman=0.5563
# epoch 35; open gates=1405.0; sparsity_loss=0.4918; running_spearman=0.5925; eval_spearman=0.5852; test_spearman=0.5541
# epoch 36; open gates=1415.0; sparsity_loss=0.4916; running_spearman=0.5915; eval_spearman=0.5863; test_spearman=0.5626
# epoch 37; open gates=1406.0; sparsity_loss=0.4914; running_spearman=0.5936; eval_spearman=0.5906; test_spearman=0.5684
# epoch 38; open gates=1398.0; sparsity_loss=0.4911; running_spearman=0.5996; eval_spearman=0.5899; test_spearman=0.5688
# epoch 39; open gates=1387.0; sparsity_loss=0.4909; running_spearman=0.6007; eval_spearman=0.5852; test_spearman=0.5568
# epoch 40; open gates=1394.0; sparsity_loss=0.4907; running_spearman=0.5960; eval_spearman=0.5875; test_spearman=0.5613
# epoch 41; open gates=1391.0; sparsity_loss=0.4904; running_spearman=0.5953; eval_spearman=0.5848; test_spearman=0.5540
# epoch 42; open gates=1403.0; sparsity_loss=0.4902; running_spearman=0.5923; eval_spearman=0.5775; test_spearman=0.5534
# epoch 43; open gates=1415.0; sparsity_loss=0.4900; running_spearman=0.5882; eval_spearman=0.5832; test_spearman=0.5588
# epoch 44; open gates=1411.0; sparsity_loss=0.4897; running_spearman=0.5940; eval_spearman=0.5854; test_spearman=0.5629
# epoch 45; open gates=1411.0; sparsity_loss=0.4895; running_spearman=0.5964; eval_spearman=0.5909; test_spearman=0.5630
# epoch 46; open gates=1404.0; sparsity_loss=0.4893; running_spearman=0.6005; eval_spearman=0.5884; test_spearman=0.5585
# epoch 47; open gates=1402.0; sparsity_loss=0.4890; running_spearman=0.5961; eval_spearman=0.5904; test_spearman=0.5645
# epoch 48; open gates=1406.0; sparsity_loss=0.4888; running_spearman=0.5968; eval_spearman=0.5906; test_spearman=0.5624
# epoch 49; open gates=1398.0; sparsity_loss=0.4886; running_spearman=0.5998; eval_spearman=0.5838; test_spearman=0.5610
# epoch 50; open gates=1390.0; sparsity_loss=0.4883; running_spearman=0.5946; eval_spearman=0.5803; test_spearman=0.5585
# epoch 51; open gates=1399.0; sparsity_loss=0.4881; running_spearman=0.5898; eval_spearman=0.5881; test_spearman=0.5651
# epoch 52; open gates=1398.0; sparsity_loss=0.4879; running_spearman=0.5974; eval_spearman=0.5876; test_spearman=0.5678
# epoch 53; open gates=1404.0; sparsity_loss=0.4876; running_spearman=0.5946; eval_spearman=0.5910; test_spearman=0.5700

# %%
torch.save(gates.detach().cpu(), f'1404gates.pt')
